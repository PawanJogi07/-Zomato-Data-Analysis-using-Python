# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("zomato.csv",encoding = 'latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.shape
# Out:
# (4394, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4394 entries, 0 to 4393
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         4394 non-null   int64
#  1   Restaurant Name       4394 non-null   object
#  2   Country Code          4394 non-null   int64
#  3   City                  4394 non-null   object
#  4   Address               4394 non-null   object
#  5   Locality              4394 non-null   object
#  6   Locality Verbose      4394 non-null   object
#  7   Longitude             4394 non-null   float64
#  8   Latitude              4394 non-null   float64
#  9   Cuisines              4385 non-null   object
#  10  Average Cost for two  4394 non-null   int64
#  11  Currency              4394 non-null   object
#  12  Has Table booking     4394 non-null   object
#  13  Has Online delivery   4394 non-null   object
#  14  Is delivering now     4394 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   4.394000e+03   4394.000000  4394.000000  4394.000000
# mean    9.028446e+06     27.283113    55.376435    25.872748
# std     8.745323e+06     69.219163    54.565049    10.493219
# min     5.300000e+01      1.000000  -157.948486   -38.634746
# 25%     3.017282e+05      1.000000    77.028818    28.434658
# 50%     5.600960e+06      1.000000    77.111097    28.532494
# 75%     1.831196e+07      1.000000    77.238927    28.634848
# max     1.850065e+07    216.000000   153.593331    52.008289
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           4394.000000  4393.000000       4393.000000   4393.000000
# mean             615.405781     1.951286          2.979308    231.038470
# std              612.208456     0.932071          1.400966    566.592104
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    1
# Price range             1
# Aggregate rating        1
# Rating color            1
# Rating text             1
# Votes                   1
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# ['Cuisines',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes']

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df_country= pd.read_excel('Country-Code.xlsx')
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
final_df = pd.merge(df,df_country,on='Country Code',how = 'left')

# %%
final_df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range             float64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                   float64
# Country                  object
# dtype: object

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.Country.value_counts()
# Out:
# Country
# India            3770
# United States     434
# Brazil             60
# UAE                60
# Australia          24
# Phillipines        22
# Singapore          20
# Canada              4
# Name: count, dtype: int64

# %%
country_names= final_df.Country.value_counts().index

# %%
country_val= final_df.Country.value_counts().values

# %%
#pie chart-Top 3 country
plt.pie(country_val[:3],labels=country_names[:3],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x11c28f750>,
# ...
#  [Text(-1.027941994348652, 0.3915804594901484, 'India'),
#   Text(1.0096329702635831, -0.4366248565493435, 'United States'),
#   Text(1.0989253828522734, -0.04861072847617467, 'Brazil')],
#  [Text(-0.560695633281083, 0.21358934154008094, '88.41%'),
#   Text(0.5507088928710453, -0.23815901266327827, '10.18%'),
#   Text(0.599413845192149, -0.026514942805186178, '1.41%')])

# %%
#zomato maximum records or transaction

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.groupby(['Aggregate rating','Rating color', 'Rating text']).size()
# Out:
# Aggregate rating  Rating color  Rating text
# 0.0               White         Not rated      706
# 1.8               Red           Poor             1
# 1.9               Red           Poor             1
# 2.0               Red           Poor             1
# 2.1               Red           Poor             4
# 2.2               Red           Poor            13
# 2.3               Red           Poor            14
# 2.4               Red           Poor            39
# 2.5               Orange        Average         40
# 2.6               Orange        Average         67
# 2.7               Orange        Average         92
# 2.8               Orange        Average        132
# 2.9               Orange        Average        138
# 3.0               Orange        Average        189
# 3.1               Orange        Average        208
# 3.2               Orange        Average        235
# 3.3               Orange        Average        216
# 3.4               Orange        Average        240
# ...

# %%
final_df.groupby(['Aggregate rating','Rating color', 'Rating text']).size().reset_index()
# Out:
#     Aggregate rating Rating color Rating text    0
# 0                0.0        White   Not rated  706
# 1                1.8          Red        Poor    1
# 2                1.9          Red        Poor    1
# 3                2.0          Red        Poor    1
# 4                2.1          Red        Poor    4
# 5                2.2          Red        Poor   13
# 6                2.3          Red        Poor   14
# 7                2.4          Red        Poor   39
# 8                2.5       Orange     Average   40
# 9                2.6       Orange     Average   67
# 10               2.7       Orange     Average   92
# 11               2.8       Orange     Average  132
# 12               2.9       Orange     Average  138
# 13               3.0       Orange     Average  189
# 14               3.1       Orange     Average  208
# 15               3.2       Orange     Average  235
# 16               3.3       Orange     Average  216
# ...

# %%
 ratings =final_df.groupby(['Aggregate rating','Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated           706
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             1
# 3                2.0          Red        Poor             1
# 4                2.1          Red        Poor             4
# 5                2.2          Red        Poor            13
# 6                2.3          Red        Poor            14
# 7                2.4          Red        Poor            39
# 8                2.5       Orange     Average            40
# 9                2.6       Orange     Average            67
# 10               2.7       Orange     Average            92
# 11               2.8       Orange     Average           132
# 12               2.9       Orange     Average           138
# 13               3.0       Orange     Average           189
# 14               3.1       Orange     Average           208
# ...

# %%
# #observation =
# 1.whwn rating is between 4.5 to 4.9 --- Excellentt
# 2.when ratings are between .0 to 3.4 -- very good
# 3. when rating is betweem 3.5  to 3.9 -- good
# 4.when rating is between 3.0 to 3.4 -- average
# 5. when rating is between 2.0 to 2.4 -- poor

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(12,6)
sns.barplot(x="Aggregate rating"	,y ="Rating Count",data = ratings)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
sns.barplot(x="Aggregate rating"	,y ="Rating Count",hue = 'Rating color',data = ratings,palette =['black','orange','yellow','green','gold']
           )
# Out:
# /var/folders/xp/x6_5htnj495dk698y4d0pzn40000gp/T/ipykernel_7193/1641567505.py:1: UserWarning:
# The palette list has fewer values (5) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x="Aggregate rating"	,y ="Rating Count",hue = 'Rating color',data = ratings,palette =['black','orange','yellow','green','gold']
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
#countplo
sns.countplot(x= "Rating color",data = ratings,palette = ['black','orange','yellow','green','gold'])
# Out:
# /var/folders/xp/x6_5htnj495dk698y4d0pzn40000gp/T/ipykernel_7193/3524032679.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x= "Rating color",data = ratings,palette = ['black','orange','yellow','green','gold'])
# /var/folders/xp/x6_5htnj495dk698y4d0pzn40000gp/T/ipykernel_7193/3524032679.py:2: UserWarning:
# The palette list has fewer values (5) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x= "Rating color",data = ratings,palette = ['black','orange','yellow','green','gold'])
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated           706
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             1
# 3                2.0          Red        Poor             1
# 4                2.1          Red        Poor             4
# 5                2.2          Red        Poor            13
# 6                2.3          Red        Poor            14
# 7                2.4          Red        Poor            39
# 8                2.5       Orange     Average            40
# 9                2.6       Orange     Average            67
# 10               2.7       Orange     Average            92
# 11               2.8       Orange     Average           132
# 12               2.9       Orange     Average           138
# 13               3.0       Orange     Average           189
# 14               3.1       Orange     Average           208
# ...

# %%
#find the countries name that has given 0 rating

# %%
final_df[final_df['Rating color']=='White'].groupby('Country').size().reset_index()
# Out:
#          Country    0
# 0         Brazil    5
# 1          India  698
# 2  United States    3

# %%
# find out which currency is used by which country

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df[['Country','Currency']].groupby(['Country','Currency']).size().reset_index()
# Out:
#          Country            Currency     0
# 0      Australia           Dollar($)    24
# 1         Brazil  Brazilian Real(R$)    60
# 2         Canada           Dollar($)     4
# 3          India  Indian Rupees(Rs.)  3770
# 4    Phillipines    Botswana Pula(P)    22
# 5      Singapore           Dollar($)    20
# 6            UAE  Emirati Diram(AED)    60
# 7  United States           Dollar($)   434

# %%
# which countries has online delevry options

# %%
final_df[final_df['Has Online delivery']== "yes"].Country.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
final_df[['Has Online delivery','Country']].groupby(['Has Online delivery','Country']).size().reset_index()
# Out:
#   Has Online delivery        Country     0
# 0                  No      Australia    24
# 1                  No         Brazil    60
# 2                  No         Canada     4
# 3                  No          India  2643
# 4                  No    Phillipines    22
# 5                  No      Singapore    20
# 6                  No            UAE    32
# 7                  No  United States   434
# 8                 Yes          India  1127
# 9                 Yes            UAE    28

# %%
final_df[['Has Online delivery']].groupby(['Has Online delivery']).size().reset_index()
# Out:
#   Has Online delivery     0
# 0                  No  3239
# 1                 Yes  1155

# %%
final_df[['Has Online delivery','Country']].groupby(['Has Online delivery','Country']).size().reset_index()
# Out:
#   Has Online delivery        Country     0
# 0                  No      Australia    24
# 1                  No         Brazil    60
# 2                  No         Canada     4
# 3                  No          India  2643
# 4                  No    Phillipines    22
# 5                  No      Singapore    20
# 6                  No            UAE    32
# 7                  No  United States   434
# 8                 Yes          India  1127
# 9                 Yes            UAE    28

# %%
city_values = final_df.City.value_counts().values

# %%
city_lables = final_df.City.value_counts().index

# %%
#create pie chart for city distrivution

# %%
final_df.City.value_counts().index
# Out:
# Index(['New Delhi', 'Gurgaon', 'Faridabad', 'Ghaziabad', 'Bhubaneshwar',
#        'Amritsar', 'Ahmedabad', 'Lucknow', 'Guwahati', 'Sharjah',
#        ...
#        'Trentham East', 'Vernonia', 'Victor Harbor', 'Vineland Station',
#        'Forrest', 'Weirton', 'Winchester Bay', 'Yorkton', 'Flaxton',
#        'Fernley'],
#       dtype='object', name='City', length=110)

# %%
plt.pie(city_values[:5],labels=city_lables[:5],autopct= '%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x12137d6d0>,
# ...
#  [Text(-0.22131081716313056, 1.0775070868475007, 'New Delhi'),
#   Text(-0.0929573504721125, -1.0960652038055059, 'Gurgaon'),
#   Text(1.0400530658690395, -0.35817540420359933, 'Faridabad'),
#   Text(1.0976924165363202, -0.07121347259229592, 'Ghaziabad'),
#   Text(1.0997732257324253, -0.022334994114521885, 'Bhubaneshwar')],
#  [Text(-0.12071499117988937, 0.5877311382804549, '56.45%'),
#   Text(-0.050704009348425, -0.5978537475302759, '34.41%'),
#   Text(0.5673016722922032, -0.19536840229287233, '7.73%'),
#   Text(0.5987413181107201, -0.038843712323070496, '0.77%'),
#   Text(0.5998763049449592, -0.01218272406246648, '0.65%')])
